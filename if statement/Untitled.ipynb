# %%
a=int(input("enter the number"))
if a % 7 == 0:
    print("it is divisible by 7")

else:
    print("it is not divisible by 7")
# Out:
# enter the number5
# it is not divisible by 7

# %%
char=(input("enter a character"))
vowels = "aeiouAEIOU"
if char in vowels:
    print(f"'{char}' is vowel")
else:
    print(f"'{char}' is not vowel")
# Out:
# enter a charactera
# 'a' is vowel

# %%
a=int(input("enter your age"))
if a >= 18:
    print("you are eligible for apply licence")
else:
     print("you are not eligible for apply licence")
# Out:
# enter your age18
# you are eligible for apply licence

# %%
str1=(input("enter a string"))
str2=(input("enter a string"))
if str1 == str2:
    print("both string are equal")
else:
    print("both string are not equal")
# Out:
# enter a stringme
# enter a stringyou
# both string are not equal

# %%
a=int(input("enter oru bill amount"))
if a >= 5000:
    print("you are eligible for discount")
else:
     print("you are not eligible for discount")
# Out:
# enter oru bill amount5000
# you are eligible for discount

# %%
a=int(input("enter a number"))
if a>10 and a<100:
    print("the number between 10 and 100")
else:
    print("the number not between 10 and 100")
# Out:
# enter a number4
# the number not between 10 and 100

# %%
a=int(input("enter your attentace percentage"))
if a >= 75:
    print("you are eligible for exam")
else:
     print("you are not eligible for exam")
# Out:
# enter your attentace percentage75
# you are eligible for exam

# %%
char=(input("enter a letter"))
if char.isupper():
    print("capital letter")
else:
    print("small letter")
# Out:
# enter a letterA
# capital letter

# %%
a=int(input("enter a number"))
if a>100 and a<999:
    print("the number is three digits")
else:
    print("the number id not three digits")
# Out:
# enter a number23
# the number id not three digits

# %%
a=float(input("enter how much gb data will you use"))
if a <= 2:
    print("low usage")
elif a>2 and a<=5:
    print("moderate usage")
else:
    print("high usage")
# Out:
# enter how much gb data will you use5.5
# high usage
