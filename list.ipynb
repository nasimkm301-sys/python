# %%
mark=[70,75,48,40,90]
print(mark[0])
# Out:
# 70

# %%
a=[70,75,48,40,90]
a.append(50)
print(a)
# Out:
# [70, 75, 48, 40, 90, 50]

# %%
a=(3,5,6,7,8)
print(a[2])
# Out:
# 6

# %%
a={20,40,60,20}
print(a)
# Out:
# {40, 20, 60}

# %%
a={"name":"anu","age":18,"place":"malappuram"}
print(a["name"])
# Out:
# anu

# %%
a="raju"
print(a[0],a[-1])
# Out:
# r u
