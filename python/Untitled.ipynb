# %%
a=int(input("enter a number:"))
if a > 100:
    print("is greater than 100")
else:
    print("less than 100")
# Out:
# enter a number:55
# less than 100

# %%
a=int(input("enter a number:"))
if a > 0:
    print("the number is positive")
else:
    print("the number is negative")
# Out:
# enter a number:-12
# the number is negative

# %%
a=int(input("enter a number:"))
if a % 2 ==0:
    print("even")
else:
    print("odd")
# Out:
# enter a number:45
# odd

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
if a==b:
    print("two numbers are equal")
else:
    print("not equal")
# Out:
# enter a number:1
# enter a number:2
# not equal

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
if a<b:
    print("the bigger number is:",b)
else:
    print("the bigger number is:",a)
# Out:
# enter a number:3
# enter a number:2
# the bigger number is: 3

# %%
a=int(input("enter your age:"))
if a>=18:
    print("you are elogible for votting")
else:
    print("you are note eligle for vote")
# Out:
# enter your age:21
# you are elogible for votting

# %%
a=int(input("enter a number:"))
if a % 5 ==0:
    print("the number is divisible by 5")
else:
    print("the number is note divisible by 5")
# Out:
# enter a number:22
# the number is note divisible by 5

# %%
a=int(input("enter a mark:"))
if a >=90:
    print("A grade")
elif a>=75:
    print("B grade")
elif a>=50:
    print("C grade")
    
else:
    print("fail")
# Out:
# enter a mark:90
# A grade

# %%
a=int(input("enter a number:"))
if a > 0:
    print("the number is positive")
elif a==0:
    print("the number is:0")
else:
    print("the number is negative")
# Out:
# enter a number:2
# the number is positive

# %%
a = int(input("enter a number: "))
b = int(input("enter a number: "))
c = int(input("enter a number: "))


if (a >= b) and (a >= c):
    print("the bigger number is:", a)

elif (b >= a) and (b >= c):
    print("the bigger number is:", b)
else:
    print("the bigger number is:", c)
# Out:
# enter a number: 22
# enter a number: 34
# enter a number: 44
# the bigger number is: 44
